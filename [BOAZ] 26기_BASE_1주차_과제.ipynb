# %% [markdown]
# # 1. ANN 과제

# %% [markdown]
# ## Backpropagation의 가중치 업데이트
#
# 다음은 17페이지에 제시된 **역전파(Backpropagation) 과정 중 가중치 업데이트 단계**를 나타낸 식이다.
#
# 가중치 업데이트 단계는 앞선 단계에서 계산된 오차의 기울기를 이용해
# 손실 함수(Error)를 최소화하는 방향으로 가중치를 조정하는 과정이며,
# 이때 사용되는 규칙은 대표적인 **최적화 기법**에 해당한다.
#
#
# $$
# W^{(l)} \leftarrow W^{(l)} - \alpha \frac{\partial E}{\partial W^{(l)}}
# $$
#
#
# ##  문제
#
# 1. 위 가중치 업데이트 식이 의미하는 **최적화 기법**이 무엇인지 설명하시오.
# 2. 위 식에서
# $$
# \frac{\partial E}{\partial W^{(l)}}
# $$
#    가 어떻게 계산되는지를 **Chain Rule(연쇄법칙)** 을 이용해 설명하시오.
#
#    (Hint: 세션 자료 하단에 제시된 최종 결과식을 참고헤 도출 과정 서술하면 됨)

# %% [markdown]
# - 답변 1 : 경사하강법. 경사하강법이란, 함수의 기울기를 이용해 현재 위치테서 가장 가파른 내리막 방향으로 조금씩 이동하며 최적의 파라미터를 찾아가는 기법을 말합니다. 위 수식에서 학습률과 기울기를 이용해 가중치를 업데이트함을 확인할 수 있습니다.
#
# - 답변 2 : 우선, 모델의 예측값과 실제 정답 사이의 오차를 계산한 후, 마지막 층 뉴런이 결과값에 얼마나 잘못 기여했는지에 대한 정도를 델타로 정의합니다.그 후, 오차 신호를 앞으로 전달하는 역전파 과정에서 연쇄법칙이 사용됩니다. 이 과정에서 계산은 다음 층의 델타 값과 가중치, 그리고 활성화 함수의 미분값의 곱으로 계산이 되며, 이렇게 구해진 현재 층의 델타 값을 구할 수 있게 됩니다. 최종적으로, 가중치 미분값은 해당 층에서의 오차 신호와 그 층으로 들어온 입력값으로 계산이 됩니다.

# %% [markdown]
# ---

# %% [markdown]
# # 2. DNN 과제

# %% [markdown]
# 다음은 세션 자료 25p의 과제의 내용이다. 자료에 주어진 조건을 바탕으로 아래 문제들을 해결하시오.
#
# ---
#
# ### **1. 파라미터 수 직접 계산하기**
# 주어진 신경망 구조(784 - 16 - 16 - 10)를 기준으로 총 학습 파라미터 수(가중치 $W$ 및 편향 $b$)를 직접 계산하시오.

# %% [markdown]
# - 답변 : 784x16(가중치1) + 1x16(편향1) + 16x16(가중치2) + 1x16(편향2) + 16x10(가중치3) + 1x10(편향3) = 13002(총 학습 파라미터 수)

# %% [markdown]
# ---
#
# ### **2. TensorFlow 모델 구현 및 검증**
# 동일한 구조의 DNN을 TensorFlow/Keras 코드로 구현하고, `model.summary()` 출력 결과와 위에서 계산한 값이 일치하는지 확인하시오. (학습 과정은 필요 X)

# %%
# !pip install tensorflow

# %%
## 1. 적절한 라이브러리를 import하세요
import tensorflow as tf
from tensorflow.keras import layers, models

## 2. 모델 설계하기
model = models.Sequential([
    # 입력
    layers.Input(shape=(784,)),
    # hidden layer1
    layers.Dense(16, activation='relu'),
    # hidden layer2
    layers.Dense(16, activation='relu'),
    # out (classification)
    layers.Dense(10, activation='softmax')
])


## 3. 모델 summary 출력
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │        12,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,002 (50.79 KB)
#  Trainable params: 13,002 (50.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---
#
# ### **3. 결과 비교**
# 1번에서 직접 계산한 학습 파라미터 수와 model.summary() 출력 결과의 Total params 값이
# 서로 일치하는지 확인하시오.

# %% [markdown]
# - 답변 : 네, 일치합니다.

# %% [markdown]
# # 3. CNN 과제

# %% [markdown]
# ---
# ## **Introduction**
#
# ![](https://miro.medium.com/v2/resize:fit:3744/format:webp/1*SGPGG7oeSvVlV5sOSQ2iZw.png)
# ([Image Credit](https://medium.com/data-science/mnist-handwritten-digits-classification-using-a-convolutional-neural-network-cnn-af5fafbc35e9))
#
# Pytorch를 사용하여 이미지와 같이 MNIST 데이터셋을 분류하는 CNN 모델을 구현해봅시다.
# Pytorch가 익숙하지 않은 분들은 [다음 튜토리얼](https://docs.pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html)을 참고해주세요.

# %% [markdown]
# ---
# ## **1. Import Libraries & Data**

# %%
# !pip install torch
# !pip install torch torchvision
# !pip install matplotlib
# Out:
# Collecting torch
#   Using cached torch-2.9.1-cp312-cp312-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: filelock in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (4.11.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Using cached torch-2.9.1-cp312-cp312-win_amd64.whl (110.9 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed sympy-1.14.0 torch-2.9.1
# Requirement already satisfied: torch in c:\users\moonyuha\anaconda3\lib\site-packages (2.9.1)
# Collecting torchvision
#   Downloading torchvision-0.24.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: filelock in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\moonyuha\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: numpy in c:\users\moonyuha\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Downloading torchvision-0.24.1-cp312-cp312-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    --------------------- ------------------ 2.4/4.3 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 12.9 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.24.1
# Requirement already satisfied: matplotlib in c:\users\moonyuha\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\moonyuha\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\moonyuha\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moonyuha\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\moonyuha\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# 필요한 라이브러리를 불러옵니다.
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np

# %%
# 이미지 변환 함수를 정의합니다.
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)) ## 1. 이미지에 Normalize를 하는 이유와 2. 다음과 같은 숫자를 사용한 이유는 무엇일까요? (답은 작성하지 않으셔도 됩니다.)
])

# 데이터셋을 불러오고, DataLoader를 사용하여 데이터를 로드합니다.
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:03<00:00, 2.65MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 144kB/s]
# 100%|██████████| 1.65M/1.65M [00:06<00:00, 266kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<?, ?B/s]

# %% [markdown]
# - 이미지에 Normalize를 하는 이유 : 활성화 함수를 통과할 때 값이 너무 크면 기울기 소실과 같은 문제가 발생할 수 있는데, 범위를 제한하면 수치적 안정성을 가지게 되어 이를 방지할 수 있습니다.
# - 다음과 같은 숫자를 사용한 이유 : 다음과 같은 숫자들은 MNIST 데이터셋의 통계값입니다. 0.1307은 MNIST 데이터셋 전체 픽셀 값의 평균, 0.3081은 표준편차 값입니다.

# %%
## 데이터셋의 크기와 차원을 확인합니다.
print(f'training set size: {len(trainset)}')
print(f'test set size: {len(testset)}\n')

print(f'training set dimension: {trainset.data.shape}')
print(f'test set dimension: {testset.data.shape}')
# Out:
# training set size: 60000
# test set size: 10000
#
# training set dimension: torch.Size([60000, 28, 28])
# test set dimension: torch.Size([10000, 28, 28])

# %% [markdown]
# ---
# ## **2. Define a Convolutional Neural Network**

# %% [markdown]
# 주어진 모델을 다시 한 번 정리해봅시다.
#
#
# **Conv_1** : 3x3 filter 32개, stride: 1, padding: 1, activation = 'relu'
# **Pool_2** : 2x2 filter, stride: 2, padding: 0
# **Conv_3** : 3x3 filter 64개, stride: 1, padding: 1, activation = 'relu'
# **Pool_4** : 2x2 filter, stride: 2, padding: 0
# **Dense_5** : 128, activation = 'relu'
# **Dense_6** : 10, activation = 'softmax'

# %%
# 아래 코드의 빈칸을 채워주세요!
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)
        self.dense5 = nn.Linear(64 * 7 * 7, 128)
        self.dense6 = nn.Linear(128,10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool2(x)
        x = torch.flatten(x, 1) # flatten layer: 2D -> 1D
        x = F.relu(self.dense5(x))
        x = self.dense6(x)
        return x

cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dense5): Linear(in_features=3136, out_features=128, bias=True)
#   (dense6): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)
        self.dense5 = nn.Linear(64 * 7 * 7, 128)
        self.dense6 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool4(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.dense5(x))
        x = self.dense6(x)
        return x

cnn = CNN()
print(cnn)

# %% [markdown]
# #### **문제: 주어진 모델에 대해, layer마다 필요한 parameter의 수를 계산하세요.**

# %% [markdown]
# 계산 : (output_channel)x(input_channel)x(kernel_size) + bias
# - Conv_1: 32x1x3x3 + 32 = 320
# - Pool_2: 0
# - Conv_3: 64x32x3x3 + 64 = 18496
# - Pool_4: 0
# - FC_5: 3136x128 + 128 = 401536
# - FC_6: 128x10 + 10 = 1290

# %%
# summary를 사용하여 정답과 계산 결과가 일치하는지 확인하세요.
# !pip install torchsummary

from torchsummary import summary

summary(cnn, (1, 28, 28))
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             320
#          MaxPool2d-2           [-1, 32, 14, 14]               0
#             Conv2d-3           [-1, 64, 14, 14]          18,496
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Linear-5                  [-1, 128]         401,536
#             Linear-6                   [-1, 10]           1,290
# ================================================================
# Total params: 421,642
# Trainable params: 421,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.36
# Params size (MB): 1.61
# Estimated Total Size (MB): 1.97
# ----------------------------------------------------------------

# %% [markdown]
# ---
# ## **3. Train a model**

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn.parameters(), lr=0.001)

# %%
for epoch in range(3):

    running_loss = 0
    acc = 0

    # training loop
    cnn.train()
    for i, data in enumerate(trainloader):
        inputs, labels = data

        # parameter gradient 초기화
        optimizer.zero_grad()

        outputs = cnn(inputs) # 모델을 통해 output 계산
        loss = criterion(outputs, labels) # loss 계산
        loss.backward() # gradient 계산 (backpropagation)
        optimizer.step() # parameter 업데이트

        running_loss += loss.item()
        if i % 100 == 99:
            print(f'[Epoch: {epoch + 1}, {i + 1:3d}] loss: {running_loss / 100:.3f}')
            running_loss = 0

    # testing loop
    cnn.eval()
    for i, data in enumerate(testloader):
        inputs, labels = data
        outputs = cnn(inputs)
        _, predicted = torch.max(outputs.data, 1)
        acc += (predicted == labels).sum().item()
    acc = acc / len(testloader.dataset)
    print(f"====== Epoch {epoch + 1} Finished, Accuracy: {acc*100:.2f}% ======")

print(f"\nTraining finished. Final accuracy: {acc*100:.2f}%")
# Out:
# [Epoch: 1, 100] loss: 0.550
# [Epoch: 1, 200] loss: 0.148
# [Epoch: 1, 300] loss: 0.110
# [Epoch: 1, 400] loss: 0.087
# [Epoch: 1, 500] loss: 0.075
# [Epoch: 1, 600] loss: 0.067
# [Epoch: 1, 700] loss: 0.058
# [Epoch: 1, 800] loss: 0.072
# [Epoch: 1, 900] loss: 0.065
# ====== Epoch 1 Finished, Accuracy: 98.74% ======
# [Epoch: 2, 100] loss: 0.044
# [Epoch: 2, 200] loss: 0.047
# [Epoch: 2, 300] loss: 0.037
# [Epoch: 2, 400] loss: 0.050
# [Epoch: 2, 500] loss: 0.035
# [Epoch: 2, 600] loss: 0.051
# [Epoch: 2, 700] loss: 0.040
# [Epoch: 2, 800] loss: 0.042
# [Epoch: 2, 900] loss: 0.036
# ====== Epoch 2 Finished, Accuracy: 98.70% ======
# [Epoch: 3, 100] loss: 0.028
# [Epoch: 3, 200] loss: 0.025
# [Epoch: 3, 300] loss: 0.028
# [Epoch: 3, 400] loss: 0.025
# [Epoch: 3, 500] loss: 0.025
# [Epoch: 3, 600] loss: 0.034
# [Epoch: 3, 700] loss: 0.021
# [Epoch: 3, 800] loss: 0.032
# [Epoch: 3, 900] loss: 0.030
# ====== Epoch 3 Finished, Accuracy: 98.86% ======
#
# Training finished. Final accuracy: 98.86%

# %% [markdown]
# ---
# ## **4. Experiment with the model**

# %%
# 기존의 모델을 원하는 대로 수정해보세요!
# ex) layer 추가, kernel size 변경, optimizer 변경, activation 함수 변경, Dropout, etc.
class newCNN(nn.Module):
    def __init__(self):
        super(newCNN, self).__init__()

        self.act = nn.LeakyReLU(negative_slope=0.1)

        self.conv1 = nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2)
        self.pool2 = nn.MaxPool2d(2, 2)

        self.drop = nn.Dropout(p=0.2)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2)
        self.pool4 = nn.MaxPool2d(2, 2)

        self.conv5 = nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=2)

        self.dense6 = nn.Linear(128 * 7 * 7, 256)
        self.dense7 = nn.Linear(256,10)

    def forward(self, x):
        x = self.act(self.conv1(x))
        x = self.pool2(x)
        x = self.drop(x)

        x = self.act(self.conv3(x))
        x = self.pool4(x)
        x = self.drop(x)

        x = self.act(self.conv5(x))
        x = self.drop(x)

        x = torch.flatten(x, 1) # flatten layer: 2D -> 1D

        x = self.act(self.dense6(x))
        x = self.drop(x)

        x = self.dense7(x)
        return x

new_cnn = newCNN()
print(new_cnn)
# Out:
# newCNN(
#   (act): LeakyReLU(negative_slope=0.1)
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop): Dropout(p=0.2, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv5): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (dense6): Linear(in_features=6272, out_features=256, bias=True)
#   (dense7): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(new_cnn.parameters(), lr=1e-3, weight_decay=1e-4)

# %%
for epoch in range(5):

    running_loss = 0
    acc = 0

    # training loop
    new_cnn.train()
    for i, data in enumerate(trainloader):
        inputs, labels = data

        # parameter gradient 초기화
        optimizer.zero_grad()

        outputs = new_cnn(inputs) # 모델을 통해 output 계산
        loss = criterion(outputs, labels) # loss 계산
        loss.backward() # gradient 계산 (backpropagation)
        optimizer.step() # parameter 업데이트

        running_loss += loss.item()
        if i % 100 == 99:
            print(f'[Epoch: {epoch + 1}, {i + 1:3d}] loss: {running_loss / 100:.3f}')
            running_loss = 0

    # testing loop
    new_cnn.eval()
    for i, data in enumerate(testloader):
        inputs, labels = data
        outputs = new_cnn(inputs)
        _, predicted = torch.max(outputs.data, 1)
        acc += (predicted == labels).sum().item()
    acc = acc / len(testloader.dataset)
    print(f"====== Epoch {epoch + 1} Finished, Accuracy: {acc*100:.2f}% ======")

print(f"\nTraining finished. Final accuracy: {acc*100:.2f}%")
# Out:
# [Epoch: 1, 100] loss: 0.497
# [Epoch: 1, 200] loss: 0.152
# [Epoch: 1, 300] loss: 0.117
# [Epoch: 1, 400] loss: 0.110
# [Epoch: 1, 500] loss: 0.086
# [Epoch: 1, 600] loss: 0.086
# [Epoch: 1, 700] loss: 0.073
# [Epoch: 1, 800] loss: 0.059
# [Epoch: 1, 900] loss: 0.075
# ====== Epoch 1 Finished, Accuracy: 98.71% ======
# [Epoch: 2, 100] loss: 0.063
# [Epoch: 2, 200] loss: 0.063
# [Epoch: 2, 300] loss: 0.053
# [Epoch: 2, 400] loss: 0.059
# [Epoch: 2, 500] loss: 0.055
# [Epoch: 2, 600] loss: 0.059
# [Epoch: 2, 700] loss: 0.046
# [Epoch: 2, 800] loss: 0.058
# [Epoch: 2, 900] loss: 0.057
# ====== Epoch 2 Finished, Accuracy: 99.12% ======
# [Epoch: 3, 100] loss: 0.045
# [Epoch: 3, 200] loss: 0.046
# [Epoch: 3, 300] loss: 0.043
# [Epoch: 3, 400] loss: 0.047
# [Epoch: 3, 500] loss: 0.052
# [Epoch: 3, 600] loss: 0.048
# [Epoch: 3, 700] loss: 0.048
# [Epoch: 3, 800] loss: 0.045
# [Epoch: 3, 900] loss: 0.044
# ====== Epoch 3 Finished, Accuracy: 98.97% ======
# [Epoch: 4, 100] loss: 0.044
# [Epoch: 4, 200] loss: 0.033
# [Epoch: 4, 300] loss: 0.035
# [Epoch: 4, 400] loss: 0.038
# [Epoch: 4, 500] loss: 0.034
# [Epoch: 4, 600] loss: 0.039
# [Epoch: 4, 700] loss: 0.050
# [Epoch: 4, 800] loss: 0.052
# [Epoch: 4, 900] loss: 0.043
# ====== Epoch 4 Finished, Accuracy: 98.84% ======
# [Epoch: 5, 100] loss: 0.038
# [Epoch: 5, 200] loss: 0.038
# [Epoch: 5, 300] loss: 0.038
# [Epoch: 5, 400] loss: 0.031
# [Epoch: 5, 500] loss: 0.036
# [Epoch: 5, 600] loss: 0.048
# [Epoch: 5, 700] loss: 0.034
# [Epoch: 5, 800] loss: 0.037
# [Epoch: 5, 900] loss: 0.040
# ====== Epoch 5 Finished, Accuracy: 99.33% ======
#
# Training finished. Final accuracy: 99.33%

# %% [markdown]
# ### **기존의 모델에서 어떤 부분을 수정하였는지 설명해주세요.**
#
# 답변 :
# - convolution layer 추가(conv5를 추가함으로써 깊이 증가 및 표현력 향상 기대)
# - kernel size 변경(기존 3x3을 5x5로 변경함으로써 전체적인 특징 학습 기대)
# - activation function 변경(LeakyReLU(0.1)로 변경함으로써 죽은 뉴런 문제 완화)
# - dropout(0.2) 추가(과적합 방지)
# - optimizer 변경(weight decay를 지정함으로써 일반화 성능 향상 기대)
# - epoch 수 증가 (더 오래 학습함으로써 성능 향상 기대)

# %% [markdown]
# ### **이러한 변경 사항이 결과에 어떻게 영향을 미쳤나요?**
#
# 답변 : 기존 98.86 성능 대비 99.33으로 성능이 향상되었음을 확인하였습니다.

# %% [markdown]
# ---
# ## **5. (정말 마지막) 이론 문제**
# convolution이 무엇인지, 그리고 이를 이용하면 이미지의 feature를 추출할 수 있음을 이해하기 위한 문제입니다.
#
# 다음과 같은 input과 kernel이 존재할 때, 발표 자료의 방식과 같이 feature map을 구하고, 그 결과를 ?에 적으시오.
# ![](https://i.imgur.com/v1wkvhW.png)

# %% [markdown]
# 정답:
# 1 0
# 0 1
